# %%
import requests
import os
from dotenv import load_dotenv

# %% [markdown]
# ### Loading Key

# %%
load_dotenv()
YOUTUBE_API_KEY = os.getenv("YOUTUBE_API_KEY")

# %%
# Tool for Extarcting Video Details from YouTube

from langchain.tools import BaseTool

class YouTubeSearchTool(BaseTool):
    name: str = "Youtube Search Tool"
    description: str = "Search YouTube videos for a given query and return top results with full descriptions"

    def _run(self, query: str):
        api_key = YOUTUBE_API_KEY

        # Step 1: Search videos
        search_url = "https://www.googleapis.com/youtube/v3/search"
        search_params = {
            "part": "snippet",
            "q": query,
            "key": api_key,
            "type": "video",
            "maxResults": 50
        }
        search_data = requests.get(search_url, params=search_params).json()
        video_ids = [item["id"]["videoId"] for item in search_data.get("items", [])]

        if not video_ids:
            return "No videos found."

        # Step 2: Fetch full descriptions
        videos_url = "https://www.googleapis.com/youtube/v3/videos"
        videos_params = {
            "part": "snippet",
            "id": ",".join(video_ids),
            "key": api_key
        }
        videos_data = requests.get(videos_url, params=videos_params).json()

        results = []
        for video in videos_data.get("items", []):
            snippet = video["snippet"]
            results.append({
                "title": snippet["title"],
                "link": f"https://www.youtube.com/watch?v={video['id']}",
                "channel": snippet["channelTitle"],
                "published": snippet["publishedAt"],
                "description": snippet["description"]
            })

        return results

# %% [markdown]
# ### Different Type of Search Queries for Extarction

# %%
query =  "Smart Fans"
query2 = "Smart Fans in India"
query3 = "Smart Fans in budget"
query4 = "Smart Fans in budget in India"
query5 = "Premium Smart Fans"
query6 = "Premium Smart Fans in India"
query7 = "Best Smart Fans"
query8 = "Best Smart Fans in India"

yt_tool = YouTubeSearchTool()

result =  yt_tool._run(query)
result2 = yt_tool._run(query2)
result3 = yt_tool._run(query3)
result4 = yt_tool._run(query4)
result5 = yt_tool._run(query5)
result6 = yt_tool._run(query6)
result7 = yt_tool._run(query7)
result8 = yt_tool._run(query8)

# %%
# Tool for Calculating Share of Voice

from typing import List, Dict
import re
from collections import defaultdict

brands = ['Crompton','Havells','Usha','Orient Electric','Atomberg','Bajaj','Polycab','LONGWAY','Activa']

class ShareOfVoiceTool(BaseTool):
    name: str = "share_of_voice"
    description: str = "Calculate the number of times each brand is mentioned in the video data"

    def _run(self, videos: List[Dict]) -> Dict:
        mention_count = defaultdict(int)

        for video in videos:
            title = video.get('title', '')
            description = video.get('description', '')
            for brand in brands:
                if re.search(rf"\b{re.escape(brand)}\b", title, re.IGNORECASE):
                    mention_count[brand] += 2
                if re.search(rf"\b{re.escape(brand)}\b", description, re.IGNORECASE):
                    mention_count[brand] += 1

        total_mentions = sum(mention_count.values())
        if total_mentions == 0:
            return {"message": "No brands were mentioned in the videos."}

        share_of_voice = {
            brand: {
                "mentions": count,
                "share_percent": round((count / total_mentions) * 100, 2)
            }
            for brand, count in mention_count.items()
        }

        return share_of_voice

# %%
shareofvoice_tool = ShareOfVoiceTool()

sov_result = shareofvoice_tool._run(result)
sov_result2 = shareofvoice_tool._run(result2)
sov_result3 = shareofvoice_tool._run(result3)
sov_result4 = shareofvoice_tool._run(result4)
sov_result5 = shareofvoice_tool._run(result5)
sov_result6 = shareofvoice_tool._run(result6)
sov_result7 = shareofvoice_tool._run(result7)
sov_result8 = shareofvoice_tool._run(result8)

# %% [markdown]
# ### Combining Query and Fetched Result so that Agent can Understand the Context

# %%
sov_result["heading"] = query
sov_result2["heading"] = query2
sov_result3["heading"] = query3
sov_result4["heading"] = query4
sov_result5["heading"] = query5
sov_result6["heading"] = query6
sov_result7["heading"] = query7
sov_result8["heading"] = query8

# %% [markdown]
# ### Pulling Local LLM

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# Appending all results into a list so we can pass a single list to LLM 

data = []
data.append(sov_result)
data.append(sov_result2)
data.append(sov_result3)
data.append(sov_result4)
data.append(sov_result5)
data.append(sov_result6)
data.append(sov_result7)
data.append(sov_result8)

# %% [markdown]
# ### Generating Report for Atomberg Based on Results

# %%
from crewai import Agent, Task, Crew, LLM

llm = LLM(model="ollama/llama3.2",temperature=0)

atomberg_agent = Agent(
    role="Market Analyst",
    goal="Analyze Atomberg's Share of Voice across multiple smart fan categories in India.",
    backstory=(
        "You are a skilled market research analyst who specializes in brand performance metrics. "
        "You excel at spotting trends, comparing categories, and delivering insights in clear, easy-to-read language."
    ),
    tools=[],
    llm = llm,
    verbose=True
)

atomberg_task = Task(
    description=f"""
You are given Share of Voice datasets for multiple smart fan categories in India.
Each dataset is a dictionary where:
- "heading" is the category name
- Other keys are brand names
- Each brand has "mentions" and "share_percent"

Your job:
1. For each dataset, extract Atomberg's mentions and share_percent.
2. Compare Atomberg's performance across all categories.
3. For each category, analyze:
   - Atomberg's raw mentions
   - Atomberg's share_percent (SOV)
   - Interpretation: what this implies about its market share in that category.
4. Identify:
   - Categories where Atomberg leads strongly
   - Categories where Atomberg is competitive
   - Categories where Atomberg is weak
5. Write a structured report with:

### Executive Summary
A concise overview of Atomberg's market presence and SOV across all categories.

### Category Breakdown
For each category:
- State the category name
- State Atomberg's mentions and share_percent in plain text
- Provide a short interpretation of what these figures suggest about market dominance or weakness (**USE NUMBERS AS IT IS FROM {data}**)
- Use bullet points or short sentences — **do not use tables or Markdown table syntax**

### Market Share & SOV Trends
- Key strengths and leadership areas
- Areas for potential growth
- Notable changes across categories

Make the output clean and readable in plain text so that it is suitable for inclusion in a PDF without formatting issues.

Data:
{data}
""",
    agent=atomberg_agent,
    expected_output="A detailed comparative market analysis report about Atomberg's Share of Voice and market share across all categories."
)

crew = Crew(
    agents=[atomberg_agent],
    tasks=[atomberg_task],
    verbose=True
)

# Run
result = crew.kickoff()
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 0f544787-bf0f-4e29-9729-aea7b95f8853                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Market Analyst                                                                                          │
# │                                                                                                                 │
# │  Task:                                                                                                          │
# │  You are given Share of Voice datasets for multiple smart fan categories in India.                              │
# │  Each dataset is a dictionary where:                                                                            │
# │  - "heading" is the category name                                                                               │
# │  - Other keys are brand names                                                                                   │
# │  - Each brand has "mentions" and "share_percent"                                                                │
# │                                                                                                                 │
# │  Your job:                                                                                                      │
# │  1. For each dataset, extract Atomberg's mentions and share_percent.                                            │
# │  2. Compare Atomberg's performance across all categories.                                                       │
# │  3. For each category, analyze:                                                                                 │
# │     - Atomberg's raw mentions                                                                                   │
# │     - Atomberg's share_percent (SOV)                                                                            │
# │     - Interpretation: what this implies about its market share in that category.                                │
# │  4. Identify:                                                                                                   │
# │     - Categories where Atomberg leads strongly                                                                  │
# │     - Categories where Atomberg is competitive                                                                  │
# │     - Categories where Atomberg is weak                                                                         │
# │  5. Write a structured report with:                                                                             │
# │                                                                                                                 │
# │  ### Executive Summary                                                                                          │
# │  A concise overview of Atomberg's market presence and SOV across all categories.                                │
# │                                                                                                                 │
# │  ### Category Breakdown                                                                                         │
# │  For each category:                                                                                             │
# │  - State the category name                                                                                      │
# │  - State Atomberg's mentions and share_percent in plain text                                                    │
# │  - Provide a short interpretation of what these figures suggest about market dominance or weakness (**USE       │
# │  NUMBERS AS IT IS FROM [{'Atomberg': {'mentions': 33, 'share_percent': 56.9}, 'Crompton': {'mentions': 9,       │
# │  'share_percent': 15.52}, 'Havells': {'mentions': 5, 'share_percent': 8.62}, 'Usha': {'mentions': 1,            │
# │  'share_percent': 1.72}, 'Orient Electric': {'mentions': 3, 'share_percent': 5.17}, 'Bajaj': {'mentions': 1,    │
# │  'share_percent': 1.72}, 'Polycab': {'mentions': 2, 'share_percent': 3.45}, 'LONGWAY': {'mentions': 1,          │
# │  'share_percent': 1.72}, 'Activa': {'mentions': 3, 'share_percent': 5.17}, 'heading': 'Smart Fans'},            │
# │  {'Atomberg': {'mentions': 67, 'share_percent': 42.41}, 'Crompton': {'mentions': 25, 'share_percent': 15.82},   │
# │  'Havells': {'mentions': 28, 'share_percent': 17.72}, 'Usha': {'mentions': 6, 'share_percent': 3.8}, 'Orient    │
# │  Electric': {'mentions': 12, 'share_percent': 7.59}, 'Bajaj': {'mentions': 3, 'share_percent': 1.9},            │
# │  'Polycab': {'mentions': 7, 'share_percent': 4.43}, 'LONGWAY': {'mentions': 1, 'share_percent': 0.63},          │
# │  'Activa': {'mentions': 9, 'share_percent': 5.7}, 'heading': 'Smart Fans in India'}, {'Atomberg': {'mentions':  │
# │  52, 'share_percent': 42.62}, 'Crompton': {'mentions': 13, 'share_percent': 10.66}, 'Havells': {'mentions':     │
# │  28, 'share_percent': 22.95}, 'Usha': {'mentions': 4, 'share_percent': 3.28}, 'Orient Electric': {'mentions':   │
# │  8, 'share_percent': 6.56}, 'Bajaj': {'mentions': 5, 'share_percent': 4.1}, 'Polycab': {'mentions': 5,          │
# │  'share_percent': 4.1}, 'LONGWAY': {'mentions': 2, 'share_percent': 1.64}, 'Activa': {'mentions': 5,            │
# │  'share_percent': 4.1}, 'heading': 'Smart Fans in budget'}, {'Crompton': {'mentions': 18, 'share_percent':      │
# │  13.14}, 'Havells': {'mentions': 31, 'share_percent': 22.63}, 'Atomberg': {'mentions': 53, 'share_percent':     │
# │  38.69}, 'Usha': {'mentions': 5, 'share_percent': 3.65}, 'Orient Electric': {'mentions': 11, 'share_percent':   │
# │  8.03}, 'Bajaj': {'mentions': 5, 'share_percent': 3.65}, 'Polycab': {'mentions': 7, 'share_percent': 5.11},     │
# │  'LONGWAY': {'mentions': 2, 'share_percent': 1.46}, 'Activa': {'mentions': 5, 'share_percent': 3.65},           │
# │  'heading': 'Smart Fans in budget in India'}, {'Crompton': {'mentions': 17, 'share_percent': 13.39},            │
# │  'Havells': {'mentions': 23, 'share_percent': 18.11}, 'Orient Electric': {'mentions': 10, 'share_percent':      │
# │  7.87}, 'Atomberg': {'mentions': 61, 'share_percent': 48.03}, 'Polycab': {'mentions': 4, 'share_percent':       │
# │  3.15}, 'Activa': {'mentions': 5, 'share_percent': 3.94}, 'Usha': {'mentions': 3, 'share_percent': 2.36},       │
# │  'Bajaj': {'mentions': 2, 'share_percent': 1.57}, 'LONGWAY': {'mentions': 2, 'share_percent': 1.57},            │
# │  'heading': 'Premium Smart Fans'}, {'Crompton': {'mentions': 25, 'share_percent': 18.12}, 'Havells':            │
# │  {'mentions': 25, 'share_percent': 18.12}, 'Atomberg': {'mentions': 52, 'share_percent': 37.68}, 'Orient        │
# │  Electric': {'mentions': 12, 'share_percent': 8.7}, 'Polycab': {'mentions': 6, 'share_percent': 4.35},          │
# │  'Activa': {'mentions': 7, 'share_percent': 5.07}, 'Usha': {'mentions': 8, 'share_percent': 5.8}, 'Bajaj':      │
# │  {'mentions': 2, 'share_percent': 1.45}, 'LONGWAY': {'mentions': 1, 'share_percent': 0.72}, 'heading':          │
# │  'Premium Smart Fans in India'}, {'Atomberg': {'mentions': 51, 'share_percent': 52.58}, 'Crompton':             │
# │  {'mentions': 12, 'share_percent': 12.37}, 'Havells': {'mentions': 14, 'share_percent': 14.43}, 'Orient         │
# │  Electric': {'mentions': 4, 'share_percent': 4.12}, 'Polycab': {'mentions': 4, 'share_percent': 4.12},          │
# │  'Activa': {'mentions': 6, 'share_percent': 6.19}, 'Usha': {'mentions': 2, 'share_percent': 2.06}, 'Bajaj':     │
# │  {'mentions': 3, 'share_percent': 3.09}, 'LONGWAY': {'mentions': 1, 'share_percent': 1.03}, 'heading': 'Best    │
# │  Smart Fans'}, {'Crompton': {'mentions': 22, 'share_percent': 14.38}, 'Havells': {'mentions': 27,               │
# │  'share_percent': 17.65}, 'Atomberg': {'mentions': 59, 'share_percent': 38.56}, 'Orient Electric':              │
# │  {'mentions': 12, 'share_percent': 7.84}, 'Polycab': {'mentions': 8, 'share_percent': 5.23}, 'Usha':            │
# │  {'mentions': 8, 'share_percent': 5.23}, 'Bajaj': {'mentions': 7, 'share_percent': 4.58}, 'LONGWAY':            │
# │  {'mentions': 2, 'share_percent': 1.31}, 'Activa': {'mentions': 8, 'share_percent': 5.23}, 'heading': 'Best     │
# │  Smart Fans in India'}]**)                                                                                      │
# │  - Use bullet points or short sentences — **do not use tables or Markdown table syntax**                        │
# │                                                                                                                 │
# │  ### Market Share & SOV Trends                                                                                  │
# │  - Key strengths and leadership areas                                                                           │
# │  - Areas for potential growth                                                                                   │
# │  - Notable changes across categories                                                                            │
# │                                                                                                                 │
# │  Make the output clean and readable in plain text so that it is suitable for inclusion in a PDF without         │
# │  formatting issues.                                                                                             │
# │                                                                                                                 │
# │  Data:                                                                                                          │
# │  [{'Atomberg': {'mentions': 33, 'share_percent': 56.9}, 'Crompton': {'mentions': 9, 'share_percent': 15.52},    │
# │  'Havells': {'mentions': 5, 'share_percent': 8.62}, 'Usha': {'mentions': 1, 'share_percent': 1.72}, 'Orient     │
# │  Electric': {'mentions': 3, 'share_percent': 5.17}, 'Bajaj': {'mentions': 1, 'share_percent': 1.72},            │
# │  'Polycab': {'mentions': 2, 'share_percent': 3.45}, 'LONGWAY': {'mentions': 1, 'share_percent': 1.72},          │
# │  'Activa': {'mentions': 3, 'share_percent': 5.17}, 'heading': 'Smart Fans'}, {'Atomberg': {'mentions': 67,      │
# │  'share_percent': 42.41}, 'Crompton': {'mentions': 25, 'share_percent': 15.82}, 'Havells': {'mentions': 28,     │
# │  'share_percent': 17.72}, 'Usha': {'mentions': 6, 'share_percent': 3.8}, 'Orient Electric': {'mentions': 12,    │
# │  'share_percent': 7.59}, 'Bajaj': {'mentions': 3, 'share_percent': 1.9}, 'Polycab': {'mentions': 7,             │
# │  'share_percent': 4.43}, 'LONGWAY': {'mentions': 1, 'share_percent': 0.63}, 'Activa': {'mentions': 9,           │
# │  'share_percent': 5.7}, 'heading': 'Smart Fans in India'}, {'Atomberg': {'mentions': 52, 'share_percent':       │
# │  42.62}, 'Crompton': {'mentions': 13, 'share_percent': 10.66}, 'Havells': {'mentions': 28, 'share_percent':     │
# │  22.95}, 'Usha': {'mentions': 4, 'share_percent': 3.28}, 'Orient Electric': {'mentions': 8, 'share_percent':    │
# │  6.56}, 'Bajaj': {'mentions': 5, 'share_percent': 4.1}, 'Polycab': {'mentions': 5, 'share_percent': 4.1},       │
# │  'LONGWAY': {'mentions': 2, 'share_percent': 1.64}, 'Activa': {'mentions': 5, 'share_percent': 4.1},            │
# │  'heading': 'Smart Fans in budget'}, {'Crompton': {'mentions': 18, 'share_percent': 13.14}, 'Havells':          │
# │  {'mentions': 31, 'share_percent': 22.63}, 'Atomberg': {'mentions': 53, 'share_percent': 38.69}, 'Usha':        │
# │  {'mentions': 5, 'share_percent': 3.65}, 'Orient Electric': {'mentions': 11, 'share_percent': 8.03}, 'Bajaj':   │
# │  {'mentions': 5, 'share_percent': 3.65}, 'Polycab': {'mentions': 7, 'share_percent': 5.11}, 'LONGWAY':          │
# │  {'mentions': 2, 'share_percent': 1.46}, 'Activa': {'mentions': 5, 'share_percent': 3.65}, 'heading': 'Smart    │
# │  Fans in budget in India'}, {'Crompton': {'mentions': 17, 'share_percent': 13.39}, 'Havells': {'mentions': 23,  │
# │  'share_percent': 18.11}, 'Orient Electric': {'mentions': 10, 'share_percent': 7.87}, 'Atomberg': {'mentions':  │
# │  61, 'share_percent': 48.03}, 'Polycab': {'mentions': 4, 'share_percent': 3.15}, 'Activa': {'mentions': 5,      │
# │  'share_percent': 3.94}, 'Usha': {'mentions': 3, 'share_percent': 2.36}, 'Bajaj': {'mentions': 2,               │
# │  'share_percent': 1.57}, 'LONGWAY': {'mentions': 2, 'share_percent': 1.57}, 'heading': 'Premium Smart Fans'},   │
# │  {'Crompton': {'mentions': 25, 'share_percent': 18.12}, 'Havells': {'mentions': 25, 'share_percent': 18.12},    │
# │  'Atomberg': {'mentions': 52, 'share_percent': 37.68}, 'Orient Electric': {'mentions': 12, 'share_percent':     │
# │  8.7}, 'Polycab': {'mentions': 6, 'share_percent': 4.35}, 'Activa': {'mentions': 7, 'share_percent': 5.07},     │
# │  'Usha': {'mentions': 8, 'share_percent': 5.8}, 'Bajaj': {'mentions': 2, 'share_percent': 1.45}, 'LONGWAY':     │
# │  {'mentions': 1, 'share_percent': 0.72}, 'heading': 'Premium Smart Fans in India'}, {'Atomberg': {'mentions':   │
# │  51, 'share_percent': 52.58}, 'Crompton': {'mentions': 12, 'share_percent': 12.37}, 'Havells': {'mentions':     │
# │  14, 'share_percent': 14.43}, 'Orient Electric': {'mentions': 4, 'share_percent': 4.12}, 'Polycab':             │
# │  {'mentions': 4, 'share_percent': 4.12}, 'Activa': {'mentions': 6, 'share_percent': 6.19}, 'Usha':              │
# │  {'mentions': 2, 'share_percent': 2.06}, 'Bajaj': {'mentions': 3, 'share_percent': 3.09}, 'LONGWAY':            │
# │  {'mentions': 1, 'share_percent': 1.03}, 'heading': 'Best Smart Fans'}, {'Crompton': {'mentions': 22,           │
# │  'share_percent': 14.38}, 'Havells': {'mentions': 27, 'share_percent': 17.65}, 'Atomberg': {'mentions': 59,     │
# │  'share_percent': 38.56}, 'Orient Electric': {'mentions': 12, 'share_percent': 7.84}, 'Polycab': {'mentions':   │
# │  8, 'share_percent': 5.23}, 'Usha': {'mentions': 8, 'share_percent': 5.23}, 'Bajaj': {'mentions': 7,            │
# │  'share_percent': 4.58}, 'LONGWAY': {'mentions': 2, 'share_percent': 1.31}, 'Activa': {'mentions': 8,           │
# │  'share_percent': 5.23}, 'heading': 'Best Smart Fans in India'}]                                                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Market Analyst                                                                                          │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Atomberg's Share of Voice (SOV) Analysis Across Multiple Smart Fan Categories in India                         │
# │                                                                                                                 │
# │  Executive Summary:                                                                                             │
# │  This report provides an in-depth analysis of Atomberg's market presence and SOV across various smart fan       │
# │  categories in India. Our findings indicate that Atomberg is a strong player in the premium segment, with       │
# │  significant leads in terms of mentions and share percent.                                                      │
# │                                                                                                                 │
# │  Category Breakdown:                                                                                            │
# │                                                                                                                 │
# │  **Smart Fans**                                                                                                 │
# │                                                                                                                 │
# │  * Atomberg: 33 mentions, 56.9% share percent                                                                   │
# │          + Interpretation: Atomberg has a dominant presence in this category, indicating its strong market      │
# │  share.                                                                                                         │
# │  * Crompton: 9 mentions, 15.52% share percent                                                                   │
# │          + Interpretation: Crompton is a significant player but trails behind Atomberg in terms of market       │
# │  share.                                                                                                         │
# │  * Havells: 5 mentions, 8.62% share percent                                                                     │
# │          + Interpretation: Havells has a relatively low presence in this category, indicating its limited       │
# │  market share.                                                                                                  │
# │                                                                                                                 │
# │  **Smart Fans in India**                                                                                        │
# │                                                                                                                 │
# │  * Atomberg: 67 mentions, 42.41% share percent                                                                  │
# │          + Interpretation: Atomberg maintains its strong lead in the Indian market, indicating its continued    │
# │  dominance.                                                                                                     │
# │  * Crompton: 25 mentions, 15.82% share percent                                                                  │
# │          + Interpretation: Crompton's presence is still significant but trails behind Atomberg in terms of      │
# │  market share.                                                                                                  │
# │  * Havells: 28 mentions, 17.72% share percent                                                                   │
# │          + Interpretation: Havells has a relatively high presence in the Indian market, indicating its strong   │
# │  market share.                                                                                                  │
# │                                                                                                                 │
# │  **Smart Fans in Budget**                                                                                       │
# │                                                                                                                 │
# │  * Atomberg: 52 mentions, 42.62% share percent                                                                  │
# │          + Interpretation: Atomberg maintains its lead in the budget segment, indicating its continued          │
# │  dominance.                                                                                                     │
# │  * Crompton: 13 mentions, 10.66% share percent                                                                  │
# │          + Interpretation: Crompton's presence is still significant but trails behind Atomberg in terms of      │
# │  market share.                                                                                                  │
# │  * Havells: 28 mentions, 22.95% share percent                                                                   │
# │          + Interpretation: Havells has a relatively high presence in the budget segment, indicating its strong  │
# │  market share.                                                                                                  │
# │                                                                                                                 │
# │  **Smart Fans in Budget in India**                                                                              │
# │                                                                                                                 │
# │  * Atomberg: 53 mentions, 38.69% share percent                                                                  │
# │          + Interpretation: Atomberg maintains its lead in the Indian budget segment, indicating its continued   │
# │  dominance.                                                                                                     │
# │  * Crompton: 18 mentions, 13.14% share percent                                                                  │
# │          + Interpretation: Crompton's presence is still significant but trails behind Atomberg in terms of      │
# │  market share.                                                                                                  │
# │  * Havells: 31 mentions, 22.63% share percent                                                                   │
# │          + Interpretation: Havells has a relatively high presence in the Indian budget segment, indicating its  │
# │  strong market share.                                                                                           │
# │                                                                                                                 │
# │  **Premium Smart Fans**                                                                                         │
# │                                                                                                                 │
# │  * Atomberg: 59 mentions, 38.56% share percent                                                                  │
# │          + Interpretation: Atomberg maintains its lead in the premium segment, indicating its continued         │
# │  dominance.                                                                                                     │
# │  * Crompton: 25 mentions, 18.12% share percent                                                                  │
# │          + Interpretation: Crompton's presence is still significant but trails behind Atomberg in terms of      │
# │  market share.                                                                                                  │
# │  * Havells: 27 mentions, 17.65% share percent                                                                   │
# │          + Interpretation: Havells has a relatively high presence in the premium segment, indicating its        │
# │  strong market share.                                                                                           │
# │                                                                                                                 │
# │  **Premium Smart Fans in India**                                                                                │
# │                                                                                                                 │
# │  * Atomberg: 51 mentions, 52.58% share percent                                                                  │
# │          + Interpretation: Atomberg maintains its lead in the Indian premium segment, indicating its continued  │
# │  dominance.                                                                                                     │
# │  * Crompton: 22 mentions, 14.38% share percent                                                                  │
# │          + Interpretation: Crompton's presence is still significant but trails behind Atomberg in terms of      │
# │  market share.                                                                                                  │
# │  * Havells: 27 mentions, 17.65% share percent                                                                   │
# │          + Interpretation: Havells has a relatively high presence in the Indian premium segment, indicating     │
# │  its strong market share.                                                                                       │
# │                                                                                                                 │
# │  **Best Smart Fans**                                                                                            │
# │                                                                                                                 │
# │  * Atomberg: 51 mentions, 52.58% share percent                                                                  │
# │          + Interpretation: Atomberg maintains its lead as the best smart fan brand, indicating its continued    │
# │  dominance.                                                                                                     │
# │  * Crompton: 12 mentions, 12.37% share percent                                                                  │
# │          + Interpretation: Crompton's presence is still significant but trails behind Atomberg in terms of      │
# │  market share.                                                                                                  │
# │  * Havells: 14 mentions, 14.43% share percent                                                                   │
# │          + Interpretation: Havells has a relatively high presence as the best smart fan brand, indicating its   │
# │  strong market share.                                                                                           │
# │                                                                                                                 │
# │  Market Share Analysis:                                                                                         │
# │  Based on our analysis, Atomberg maintains its lead across various categories, including premium and budget     │
# │  segments. Crompton and Havells trail behind Atomberg in terms of market share, but still have significant      │
# │  presences in their respective segments.                                                                        │
# │                                                                                                                 │
# │  Conclusion:                                                                                                    │
# │  This report provides an in-depth analysis of Atomberg's market presence and SOV across multiple smart fan      │
# │  categories in India. Our findings indicate that Atomberg is a strong player in the premium segment, with       │
# │  significant leads in terms of mentions and share percent. Crompton and Havells trail behind Atomberg in terms  │
# │  of market share but still have significant presences in their respective segments.                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: e8771397-a718-4dda-a4cb-d82b594b109d                                                                     │
# │  Agent: Market Analyst                                                                                          │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 0f544787-bf0f-4e29-9729-aea7b95f8853                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: Atomberg's Share of Voice (SOV) Analysis Across Multiple Smart Fan Categories in India           │
# │                                                                                                                 │
# │  Executive Summary:                                                                                             │
# │  This report provides an in-depth analysis of Atomberg's market presence and SOV across various smart fan       │
# │  categories in India. Our findings indicate that Atomberg is a strong player in the premium segment, with       │
# │  significant leads in terms of mentions and share percent.                                                      │
# │                                                                                                                 │
# │  Category Breakdown:                                                                                            │
# │                                                                                                                 │
# │  **Smart Fans**                                                                                                 │
# │                                                                                                                 │
# │  * Atomberg: 33 mentions, 56.9% share percent                                                                   │
# │          + Interpretation: Atomberg has a dominant presence in this category, indicating its strong market      │
# │  share.                                                                                                         │
# │  * Crompton: 9 mentions, 15.52% share percent                                                                   │
# │          + Interpretation: Crompton is a significant player but trails behind Atomberg in terms of market       │
# │  share.                                                                                                         │
# │  * Havells: 5 mentions, 8.62% share percent                                                                     │
# │          + Interpretation: Havells has a relatively low presence in this category, indicating its limited       │
# │  market share.                                                                                                  │
# │                                                                                                                 │
# │  **Smart Fans in India**                                                                                        │
# │                                                                                                                 │
# │  * Atomberg: 67 mentions, 42.41% share percent                                                                  │
# │          + Interpretation: Atomberg maintains its strong lead in the Indian market, indicating its continued    │
# │  dominance.                                                                                                     │
# │  * Crompton: 25 mentions, 15.82% share percent                                                                  │
# │          + Interpretation: Crompton's presence is still significant but trails behind Atomberg in terms of      │
# │  market share.                                                                                                  │
# │  * Havells: 28 mentions, 17.72% share percent                                                                   │
# │          + Interpretation: Havells has a relatively high presence in the Indian market, indicating its strong   │
# │  market share.                                                                                                  │
# │                                                                                                                 │
# │  **Smart Fans in Budget**                                                                                       │
# │                                                                                                                 │
# │  * Atomberg: 52 mentions, 42.62% share percent                                                                  │
# │          + Interpretation: Atomberg maintains its lead in the budget segment, indicating its continued          │
# │  dominance.                                                                                                     │
# │  * Crompton: 13 mentions, 10.66% share percent                                                                  │
# │          + Interpretation: Crompton's presence is still significant but trails behind Atomberg in terms of      │
# │  market share.                                                                                                  │
# │  * Havells: 28 mentions, 22.95% share percent                                                                   │
# │          + Interpretation: Havells has a relatively high presence in the budget segment, indicating its strong  │
# │  market share.                                                                                                  │
# │                                                                                                                 │
# │  **Smart Fans in Budget in India**                                                                              │
# │                                                                                                                 │
# │  * Atomberg: 53 mentions, 38.69% share percent                                                                  │
# │          + Interpretation: Atomberg maintains its lead in the Indian budget segment, indicating its continued   │
# │  dominance.                                                                                                     │
# │  * Crompton: 18 mentions, 13.14% share percent                                                                  │
# │          + Interpretation: Crompton's presence is still significant but trails behind Atomberg in terms of      │
# │  market share.                                                                                                  │
# │  * Havells: 31 mentions, 22.63% share percent                                                                   │
# │          + Interpretation: Havells has a relatively high presence in the Indian budget segment, indicating its  │
# │  strong market share.                                                                                           │
# │                                                                                                                 │
# │  **Premium Smart Fans**                                                                                         │
# │                                                                                                                 │
# │  * Atomberg: 59 mentions, 38.56% share percent                                                                  │
# │          + Interpretation: Atomberg maintains its lead in the premium segment, indicating its continued         │
# │  dominance.                                                                                                     │
# │  * Crompton: 25 mentions, 18.12% share percent                                                                  │
# │          + Interpretation: Crompton's presence is still significant but trails behind Atomberg in terms of      │
# │  market share.                                                                                                  │
# │  * Havells: 27 mentions, 17.65% share percent                                                                   │
# │          + Interpretation: Havells has a relatively high presence in the premium segment, indicating its        │
# │  strong market share.                                                                                           │
# │                                                                                                                 │
# │  **Premium Smart Fans in India**                                                                                │
# │                                                                                                                 │
# │  * Atomberg: 51 mentions, 52.58% share percent                                                                  │
# │          + Interpretation: Atomberg maintains its lead in the Indian premium segment, indicating its continued  │
# │  dominance.                                                                                                     │
# │  * Crompton: 22 mentions, 14.38% share percent                                                                  │
# │          + Interpretation: Crompton's presence is still significant but trails behind Atomberg in terms of      │
# │  market share.                                                                                                  │
# │  * Havells: 27 mentions, 17.65% share percent                                                                   │
# │          + Interpretation: Havells has a relatively high presence in the Indian premium segment, indicating     │
# │  its strong market share.                                                                                       │
# │                                                                                                                 │
# │  **Best Smart Fans**                                                                                            │
# │                                                                                                                 │
# │  * Atomberg: 51 mentions, 52.58% share percent                                                                  │
# │          + Interpretation: Atomberg maintains its lead as the best smart fan brand, indicating its continued    │
# │  dominance.                                                                                                     │
# │  * Crompton: 12 mentions, 12.37% share percent                                                                  │
# │          + Interpretation: Crompton's presence is still significant but trails behind Atomberg in terms of      │
# │  market share.                                                                                                  │
# │  * Havells: 14 mentions, 14.43% share percent                                                                   │
# │          + Interpretation: Havells has a relatively high presence as the best smart fan brand, indicating its   │
# │  strong market share.                                                                                           │
# │                                                                                                                 │
# │  Market Share Analysis:                                                                                         │
# │  Based on our analysis, Atomberg maintains its lead across various categories, including premium and budget     │
# │  segments. Crompton and Havells trail behind Atomberg in terms of market share, but still have significant      │
# │  presences in their respective segments.                                                                        │
# │                                                                                                                 │
# │  Conclusion:                                                                                                    │
# │  This report provides an in-depth analysis of Atomberg's market presence and SOV across multiple smart fan      │
# │  categories in India. Our findings indicate that Atomberg is a strong player in the premium segment, with       │
# │  significant leads in terms of mentions and share percent. Crompton and Havells trail behind Atomberg in terms  │
# │  of market share but still have significant presences in their respective segments.                             │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
print(result)
# Out:
# **Executive Summary**
#
# Atomberg's market presence is strong across multiple smart fan categories in India. The company leads strongly in some categories, while being competitive in others. Atomberg's raw mentions are highest in the "Premium Smart Fans" category, indicating its dominance in this segment.
#
# **Category Breakdown**
#
# * **Smart Fans**
# 	+ Atomberg: 33 mentions, 56.9% share_percent
# 	+ Interpretation: Atomberg is a leading brand in the smart fan market, with a significant share of voice.
# * **Smart Fans in India**
# 	+ Atomberg: 67 mentions, 42.41% share_percent
# 	+ Interpretation: Atomberg's performance in this category suggests it has a strong presence in the Indian market for smart fans.
# * **Smart Fans in budget**
# 	+ Atomberg: 53 mentions, 38.69% share_percent
# 	+ Interpretation: Atomberg is a leading brand in the budget segment of the smart fan market, indicating its affordability and value proposition.
# * **Premium Smart Fans**
# 	+ Atomberg: 59 mentions, 38.56% share_percent
# 	+ Interpretation: Atomberg's dominance in this category suggests it offers high-quality premium products that cater to consumers' needs.
# * **Best Smart Fans**
# 	+ Atomberg: 51 mentions, 52.58% share_percent
# 	+ Interpretation: Atomberg's performance in this category indicates its reputation for producing the best smart fans, which is a key differentiator.
#
# **Market Share & SOV Trends**
#
# * Key strengths and leadership areas:
# 	+ Premium Smart Fans: Atomberg's dominance in this category suggests it has a strong presence in the high-end segment.
# 	+ Smart Fans in budget: Atomberg's leading position in this category indicates its ability to offer affordable products that meet consumers' needs.
# * Areas for potential growth:
# 	+ Smart Fans in India (compared to other categories): Atomberg's performance in this category suggests it has a strong presence, but there may be opportunities to expand further.
# * Notable changes across categories:
# 	+ In the "Smart Fans" category, Atomberg's share_percent decreased compared to other categories. This could indicate that the company is focusing on higher-end products or that its market share is being eroded by competitors.
# 	+ In the "Premium Smart Fans" category, Atomberg's share_percent increased compared to other categories. This suggests that the company is successfully catering to consumers' needs for high-quality premium products.
#
# **Comparison with Competitors**
#
# * Crompton: Crompton performs well in some categories (e.g., Smart Fans in India), but its overall market presence is weaker than Atomberg's.
# * Havells: Havells has a strong presence in the "Smart Fans" category, but its share_percent is lower than Atomberg's. This suggests that Havells may be focusing on other areas of the market.
# * Orient Electric: Orient Electric performs well in some categories (e.g., Smart Fans in budget), but its overall market presence is weaker than Atomberg's.
#
# Overall, Atomberg's strong performance across multiple smart fan categories in India indicates its leadership position in the market. The company's ability to offer high-quality products at affordable prices has contributed to its success. However, there may be opportunities for growth and expansion into new areas of the market.

# %% [markdown]
# ### Converting and Saving PDF

# %%
import markdown
from weasyprint import HTML

# Suppose this is your CrewAI result
markdown_text = result.raw  # LLM output with Markdown formatting

# Convert Markdown to HTML
html_content = markdown.markdown(markdown_text)

# Optional: add basic CSS for better styling
html_with_styles = f"""
<html>
<head>
<style>
body {{ font-family: Arial, sans-serif; line-height: 1.6; }}
h1, h2, h3 {{ color: #2c3e50; }}
strong {{ font-weight: bold; }}
em {{ font-style: italic; }}
ul {{ margin: 0; padding-left: 20px; }}
li {{ margin-bottom: 5px; }}
</style>
</head>
<body>
{html_content}
</body>
</html>
"""

# Render to PDF
HTML(string=html_with_styles).write_pdf("atomberg_report.pdf")

print("PDF saved as atomberg_report.pdf with proper formatting!")
# Out:
# PDF saved as atomberg_report.pdf with proper formatting!

# %% [markdown]
# ### Converting Dicts into DataFrames for Visualizations

# %%
import pandas as pd

df =  pd.DataFrame.from_dict(sov_result)
df2 = pd.DataFrame.from_dict(sov_result2)
df3 = pd.DataFrame.from_dict(sov_result3)
df4 = pd.DataFrame.from_dict(sov_result4)
df5 = pd.DataFrame.from_dict(sov_result5)
df6 = pd.DataFrame.from_dict(sov_result6)
df7 = pd.DataFrame.from_dict(sov_result7)
df8 = pd.DataFrame.from_dict(sov_result8)

def table(df):
        df = df.T
        df = df.reset_index()
        df = df.rename(columns={'index': 'Company'})
        df = df[df['Company'] != 'heading'].reset_index(drop=True)
        return df

df = table(df)
df2 = table(df2)
df3 = table(df3)
df4 = table(df4)
df5 = table(df5)
df6 = table(df6)
df7 = table(df7)
df8 = table(df8)

# # Saving DataFrames 

df.to_excel('Smart Fans.xlsx',index=False)
df2.to_excel('Smart Fans in India.xlsx',index=False)
df3.to_excel('Smart Fans in budget.xlsx',index=False)
df4.to_excel('Smart Fans in budget in India.xlsx',index=False)
df5.to_excel('Premium Smart Fans.xlsx',index=False)
df6.to_excel('Premium Smart Fans in India.xlsx',index=False)
df7.to_excel('Best Smart Fans.xlsx',index=False)
df8.to_excel('Best Smart Fans in India.xlsx',index=False)

# %%
df5
# Out:
#            Company mentions share_percent
# 0         Crompton     17.0         13.39
# 1          Havells     23.0         18.11
# 2  Orient Electric     10.0          7.87
# 3         Atomberg     61.0         48.03
# 4          Polycab      4.0          3.15
# 5           Activa      5.0          3.94
# 6             Usha      3.0          2.36
# 7            Bajaj      2.0          1.57
# 8          LONGWAY      2.0          1.57
